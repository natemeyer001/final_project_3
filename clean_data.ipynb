# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Import data

df = pd.read_csv(Path('spotify_dataset.csv'))
df
# Out:
#       Index  Highest Charting Position  Number of Times Charted  \
# 0         1                          1                        8
# 1         2                          2                        3
# 2         3                          1                       11
# 3         4                          3                        5
# 4         5                          5                        1
# ...     ...                        ...                      ...
# 1551   1552                        195                        1
# 1552   1553                        196                        1
# 1553   1554                        197                        1
# 1554   1555                        198                        1
# 1555   1556                        199                        1
#
#      Week of Highest Charting                           Song Name     Streams  \
# 0      2021-07-23--2021-07-30                             Beggin'  48,633,449
# ...

# %%
df.dtypes
# Out:
# Index                         int64
# Highest Charting Position     int64
# Number of Times Charted       int64
# Week of Highest Charting     object
# Song Name                    object
# Streams                      object
# Artist                       object
# Artist Followers             object
# Song ID                      object
# Genre                        object
# Release Date                 object
# Weeks Charted                object
# Popularity                   object
# Danceability                 object
# Energy                       object
# Loudness                     object
# Speechiness                  object
# Acousticness                 object
# Liveness                     object
# Tempo                        object
# Duration (ms)                object
# Valence                      object
# Chord                        object
# dtype: object

# %%
# Remove rows that contain incorrect or incomplete data 

df.drop(df[df["Genre"] == "[]"].index, inplace = True)
df.drop(df[df["Popularity"] == " "].index, inplace = True)

# %%
# Clean data to recognize numeric metrics as numbers & drop not needed columns

df["Streams"] = df["Streams"].replace({",":""}, regex=True).apply(pd.to_numeric,1)
df['Artist Followers'] = pd.to_numeric(df['Artist Followers'])
df['Popularity'] = pd.to_numeric(df['Popularity'])
df['Danceability'] = pd.to_numeric(df['Danceability'])
df['Energy'] = pd.to_numeric(df['Energy'])
df['Loudness'] = pd.to_numeric(df['Loudness'])
df['Speechiness'] = pd.to_numeric(df['Speechiness'])
df['Acousticness'] = pd.to_numeric(df['Acousticness'])
df['Liveness'] = pd.to_numeric(df['Liveness'])
df['Tempo'] = pd.to_numeric(df['Tempo'])
df['Duration (ms)'] = pd.to_numeric(df['Duration (ms)'])
df['Valence'] = pd.to_numeric(df['Valence'])
df['Release Date'] = pd.to_datetime(df["Release Date"])
df.drop(["Index","Week of Highest Charting","Weeks Charted"], axis=1, inplace=True)

# %%
df.dtypes
# Out:
# Highest Charting Position             int64
# Number of Times Charted               int64
# Song Name                            object
# Streams                               int64
# Artist                               object
# Artist Followers                      int64
# Song ID                              object
# Genre                                object
# Release Date                 datetime64[ns]
# Popularity                            int64
# Danceability                        float64
# Energy                              float64
# Loudness                            float64
# Speechiness                         float64
# Acousticness                        float64
# Liveness                            float64
# Tempo                               float64
# Duration (ms)                         int64
# Valence                             float64
# Chord                                object
# dtype: object

# %%
genre_df = df

# %%
genre_df.loc[df["Genre"].str.contains("k-pop"),'Genre'] = "k-pop"
genre_df = df.loc[df["Genre"].str.contains(" rap"),'Genre'] = "hip hop"
genre_df = df.loc[df["Genre"].str.contains("brooklyn drill"),'Genre'] = "hip hop"
genre_df = df.loc[df["Genre"].str.contains("hip hop"),'Genre'] = "hip hop"
clean_df = df.loc[df["Genre"].str.contains("latin"),'Genre'] = "latin"
clean_df.groupby("Genre")["Streams"].nunique().sort_values(ascending=False)

# %%
df.head(40)

# %%
df.loc[df["Genre"].str.contains("pop"),'Genre'] = "pop"
df.loc[df["Genre"].str.contains("hip hop"),'Genre'] = "hip hop"
df.loc[df["Genre"].str.contains("rock"),'Genre'] = "rock"
df.loc[df["Genre"].str.contains("rap"),'Genre'] = "rap"
df.loc[df["Genre"].str.contains("latin"),'Genre'] = "latin"
df.loc[df["Genre"].str.contains("funk"),'Genre'] = "soul"
df.loc[df["Genre"].str.contains("punk"),'Genre'] = "rock"
df.loc[df["Genre"].str.contains("adult standards"),'Genre'] = "jazz"
df.loc[df["Genre"].str.contains("soul"),'Genre'] = "soul"
df.loc[df["Genre"].str.contains("r&b"),'Genre'] = "soul"
df.loc[df["Genre"].str.contains("house"),'Genre'] = "other"
df.loc[df["Genre"].str.contains("trance"),'Genre'] = "other"
df.loc[df["Genre"].str.contains("trance"),'Genre'] = "other"
df.loc[df["Genre"].str.contains("euro"),'Genre'] = "other"
df.loc[df["Genre"].str.contains("mexican"),'Genre'] = "latin"
df.loc[df["Genre"].str.contains("mexican"),'Genre'] = "espanol"
df.Genre.unique()

# %%
df.groupby("Genre")["Streams"].nunique().sort_values(ascending=False)
