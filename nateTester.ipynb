# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

# %matplotlib inline
import numpy as np
import seaborn as sb

from sklearn.metrics import r2_score

# %%
df = pd.read_csv("clean_data.csv")
df.head()
# Out:
#    Highest Charting Position  Number of Times Charted  \
# 0                          1                        8
# 1                          2                        3
# 2                          1                       11
# 3                          3                        5
# 4                          5                        1
#
#                            Song Name   Streams          Artist  \
# 0                            Beggin'  48633449        Måneskin
# 1          STAY (with Justin Bieber)  47248719   The Kid LAROI
# 2                           good 4 u  40162559  Olivia Rodrigo
# 3                         Bad Habits  37799456      Ed Sheeran
# 4  INDUSTRY BABY (feat. Jack Harlow)  33948454       Lil Nas X
#
#    Artist Followers                 Song ID  \
# 0           3377762  3Wrjm47oTz2sjIgck11l5e
# 1           2230022  5HCyWlXZPP0y6Gqq8TgA20
# 2           6266514  4ZtFanR9U6ndgddUvNcjcG
# 3          83293380  6PQ88X9TkUIAUIZJHW2upE
# ...

# %% [markdown]
# # Check for Single Linear Relationships with Number of Times Charted as the target

# %%
#features = ["Popularity", "Danceability", "Energy", "Loudness", "Speechiness", 
#            "Acousticness", "Liveness", "Tempo", "Duration (ms)", "Valence"]

# %%
plt.scatter(x=df["Popularity"], y=df["Number of Times Charted"])
plt.xlabel("Popularity")
plt.ylabel('Number of Times Charted')
plt.show()

# %%
plt.scatter(x=df["Danceability"], y=df["Number of Times Charted"])
plt.xlabel("Danceability")
plt.ylabel('Number of Times Charted')
plt.show()

# %%
plt.scatter(x=df["Energy"], y=df["Number of Times Charted"])
plt.xlabel("Energy")
plt.ylabel('Number of Times Charted')
plt.show()

# %%
plt.scatter(x=df["Loudness"], y=df["Number of Times Charted"])
plt.xlabel("Loudness")
plt.ylabel('Number of Times Charted')
plt.show()

# %%
plt.scatter(x=df["Speechiness"], y=df["Number of Times Charted"])
plt.xlabel("Speechiness")
plt.ylabel('Number of Times Charted')
plt.show()

# %%
plt.scatter(x=df["Acousticness"], y=df["Number of Times Charted"])
plt.xlabel("Acousticness")
plt.ylabel('Number of Times Charted')
plt.show()

# %%
plt.scatter(x=df["Liveness"], y=df["Number of Times Charted"])
plt.xlabel("Liveness")
plt.ylabel('Number of Times Charted')
plt.show()

# %%
plt.scatter(x=df["Tempo"], y=df["Number of Times Charted"])
plt.xlabel("Tempo")
plt.ylabel('Number of Times Charted')
plt.show()

# %%
plt.scatter(x=df["Duration (ms)"], y=df["Number of Times Charted"])
plt.xlabel("Duration (ms)")
plt.ylabel('Number of Times Charted')
plt.show()

# %%
plt.scatter(x=df["Valence"], y=df["Number of Times Charted"])
plt.xlabel("Valence")
plt.ylabel('Number of Times Charted')
plt.show()

# %% [markdown]
# # Check for Single Linear Relationships with Streams as the target

# %% [markdown]
# #### Popularity

# %%
plt.scatter(x=df["Popularity"], y=df["Streams"])
plt.xlabel("Popularity")
plt.ylabel('Streams')
plt.show()

# %% [markdown]
# With log - maybe remove songs that have a popularity of 0?

# %%
plt.scatter(x=df["Popularity"], y=df["Streams"])
plt.xlabel("Popularity")
plt.ylabel('Streams')
plt.yscale("log")
plt.show()

# %% [markdown]
# #### Danceability

# %%
plt.scatter(x=df["Danceability"], y=df["Streams"])
plt.xlabel("Danceability")
plt.ylabel('Streams')
plt.show()

# %%
plt.scatter(x=df["Danceability"], y=df["Streams"])
plt.xlabel("Danceability")
plt.ylabel('Streams')
plt.yscale("log")
plt.show()

# %% [markdown]
# #### Energy

# %%
plt.scatter(x=df["Energy"], y=df["Streams"])
plt.xlabel("Energy")
plt.ylabel('Streams')
plt.show()

# %%
plt.scatter(x=df["Energy"], y=df["Streams"])
plt.xlabel("Energy")
plt.ylabel('Streams')
plt.yscale("log")
plt.show()

# %% [markdown]
# #### Loudness

# %%
plt.scatter(x=df["Loudness"], y=df["Streams"])
plt.xlabel("Loudness")
plt.ylabel("Streams")
plt.show()

# %%
plt.scatter(x=df["Loudness"], y=df["Streams"])
plt.xlabel("Loudness")
plt.ylabel("Streams")
plt.yscale("log")
plt.show()

# %% [markdown]
# #### Speechiness

# %%
plt.scatter(x=df["Speechiness"], y=df["Streams"])
plt.xlabel("Speechiness")
plt.ylabel("Streams")
plt.show()

# %%
plt.scatter(x=df["Speechiness"], y=df["Streams"])
plt.xlabel("Speechiness")
plt.ylabel("Streams")
plt.yscale("log")
plt.show()

# %% [markdown]
# #### Acousticness

# %%
plt.scatter(x=df["Acousticness"], y=df["Streams"])
plt.xlabel("Acousticness")
plt.ylabel('Streams')
plt.show()

# %%
plt.scatter(x=df["Acousticness"], y=df["Streams"])
plt.xlabel("Acousticness")
plt.ylabel('Streams')
plt.yscale("log")
plt.show()

# %% [markdown]
# #### Liveness

# %%
plt.scatter(x=df["Liveness"], y=df["Streams"])
plt.xlabel("Liveness")
plt.ylabel("Streams")
plt.show()

# %%
plt.scatter(x=df["Liveness"], y=df["Streams"])
plt.xlabel("Liveness")
plt.ylabel("Streams")
plt.yscale("log")
plt.show()

# %% [markdown]
# #### Tempo

# %%
plt.scatter(x=df["Tempo"], y=df["Streams"])
plt.xlabel("Tempo")
plt.ylabel("Streams")
plt.show()

# %%
plt.scatter(x=df["Tempo"], y=df["Streams"])
plt.xlabel("Tempo")
plt.ylabel("Streams")
plt.yscale("log")
plt.show()

# %% [markdown]
# #### Duration

# %%
plt.scatter(x=df["Duration (ms)"], y=df["Streams"])
plt.xlabel("Duration (ms)")
plt.ylabel("Streams")
plt.show()

# %%
plt.scatter(x=df["Duration (ms)"], y=df["Streams"])
plt.xlabel("Duration (ms)")
plt.ylabel("Streams")
plt.yscale("log")
plt.show()

# %% [markdown]
# #### Valence

# %%
plt.scatter(x=df["Valence"], y=df["Streams"])
plt.xlabel("Valence")
plt.ylabel("Streams")
plt.show()

# %%
plt.scatter(x=df["Valence"], y=df["Streams"])
plt.xlabel("Valence")
plt.ylabel("Streams")
plt.yscale("log")
plt.show()

# %% [markdown]
# ## Correlation

# %%
corr = df.corr()

# %%
plt.figure(figsize=(12,12))
sb.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(x=df["Popularity"], y=df["Loudness"])
plt.xlabel("Popularity")
plt.ylabel("Loudness")
plt.show()

# %%
new_df = df.loc[df["Popularity"] > 20]

# %%
plt.scatter(x=new_df["Popularity"], y=new_df["Loudness"])
plt.xlabel("Popularity")
plt.ylabel("Loudness")
plt.show()

# %%
plt.scatter(x=new_df["Energy"], y=new_df["Loudness"])
plt.xlabel("Energy")
plt.ylabel("Loudness")
plt.show()

# %%
corr2 = new_df.corr()
plt.figure(figsize=(12,12))
sb.heatmap(corr2, annot=True, cmap="GnBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Linear Regression

# %%
X = df["Popularity"].values.reshape(-1,1)
y = df["Streams"]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

r2 = r2_score(y_test, y_pred)
print(f"The r^2 score for the model is {round(r2,3)}")
# Out:
# The r^2 score for the model is -0.031

# %% [markdown]
# ## Use new_df to see if removing non-popular songs  improves the r^2

# %%
X = new_df["Popularity"].values.reshape(-1,1)
y = new_df["Streams"]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

r2 = r2_score(y_test, y_pred)
print(f"The r^2 score for the model is {round(r2,3)}")
# Out:
# The r^2 score for the model is -0.021

# %%
X = df["Artist Followers"].values.reshape(-1,1)
y = df["Streams"]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

r2 = r2_score(y_test, y_pred)
print(f"The r^2 score for the model is {round(r2,3)}")
# Out:
# The r^2 score for the model is 0.015

# %%
X = new_df["Artist Followers"].values.reshape(-1,1)
y = new_df["Streams"]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

r2 = r2_score(y_test, y_pred)
print(f"The r^2 score for the model is {round(r2,3)}")
# Out:
# The r^2 score for the model is 0.024

# %% [markdown]
# ## Multiple Linear Regression with "Popularity" and "Artist Followers

# %%
X = df[["Popularity","Artist Followers"]]
y = df["Streams"]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

r2 = r2_score(y_test, y_pred)
print(f"The r^2 score for the model is {round(r2,3)}")
# Out:
# The r^2 score for the model is -0.011

# %%
X = new_df[["Popularity","Artist Followers"]]
y = new_df["Streams"]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

r2 = r2_score(y_test, y_pred)
print(f"The r^2 score for the model is {round(r2,3)}")
# Out:
# The r^2 score for the model is 0.006

# %% [markdown]
# ## Test all features

# %%
X = df[["Artist Followers", "Popularity", "Danceability", "Energy",
       "Loudness", "Speechiness", "Acousticness", "Liveness",
       "Tempo", "Duration (ms)", "Valence"]]
y = df["Streams"]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

r2 = r2_score(y_test, y_pred)
print(f"The r^2 score for the model is {round(r2,3)}")
# Out:
# The r^2 score for the model is -0.01

# %%
X = new_df[["Artist Followers", "Popularity", "Danceability", "Energy",
       "Loudness", "Speechiness", "Acousticness", "Liveness",
       "Tempo", "Duration (ms)", "Valence"]]
y = new_df["Streams"]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

r2 = r2_score(y_test, y_pred)
print(f"The r^2 score for the model is {round(r2,3)}")
# Out:
# The r^2 score for the model is -0.008
